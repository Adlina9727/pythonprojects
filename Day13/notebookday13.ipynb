# %%
vector1 = [3,4,5]
vector2 = [2,4,1]

# %%
matrix2 = [vector1,vector2]
#[2,4,10] as a result 
# 2 as a result
print(matrix2)
print(vector2)
print(vector2[0])
print(matrix2[0][1])
print(matrix2[1][2])
# Out:
# [[3, 4, 5], [2, 4, 1]]
# [2, 4, 1]
# 2
# 4
# 1

# %%
list2 = [3,4,5,'idress',4.5, [3,['a','b'],5]]
print(list2[5])
print(list2[5][1][0])
# Out:
# [3, ['a', 'b'], 5]
# a
