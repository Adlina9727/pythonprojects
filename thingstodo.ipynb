# %%
import morefun.funthing
morefun.funthing.Car("Corolla","Toyota", 2020)
my_car = morefun.funthing.Car("Corolla","Toyota", 2020)
print(my_car.display_info())
print(my_car.display_name())
# Out:
# 2020Toyota
# Welcome Corolla
